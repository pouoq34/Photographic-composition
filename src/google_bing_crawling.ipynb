# %%
from icrawler.builtin import BaiduImageCrawler, BingImageCrawler, GoogleImageCrawler

google_crawler = GoogleImageCrawler(
    feeder_threads=1,
    parser_threads=1,
    downloader_threads=4,
    storage={'root_dir': 'your_image_dir'})
filters = dict(
    date=((2019, 1, 1), (2019, 11, 30)))
google_crawler.crawl(keyword='롯데월드타워', filters=filters, offset=0, max_num=1000,
                     min_size=(200,200), max_size=None, file_idx_offset=0)

bing_crawler = BingImageCrawler(downloader_threads=4,
                                storage={'root_dir': 'your_image_dir'})
bing_crawler.crawl(keyword='롯데월드타워', filters=None, offset=0, max_num=1000)

baidu_crawler = BaiduImageCrawler(storage={'root_dir': 'your_image_dir'})
baidu_crawler.crawl(keyword='롯데월드타워', offset=0, max_num=1000,
                    min_size=(200,200), max_size=None)
# Out:
# 2020-02-05 14:52:06,699 - INFO - icrawler.crawler - start crawling...
# 2020-02-05 14:52:06,701 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2020-02-05 14:52:06,709 - INFO - icrawler.crawler - starting 1 parser threads...
# 2020-02-05 14:52:06,713 - INFO - icrawler.crawler - starting 4 downloader threads...
# 2020-02-05 14:52:07,600 - INFO - parser - parsing result page https://www.google.com/search?q=%EB%A1%AF%EB%8D%B0%EC%9B%94%EB%93%9C%ED%83%80%EC%9B%8C&ijn=0&start=0&tbs=cdr%3A1%2Ccd_min%3A01%2F01%2F2019%2Ccd_max%3A11%2F30%2F2019&tbm=isch
# 2020-02-05 14:52:08,122 - INFO - parser - parsing result page https://www.google.com/search?q=%EB%A1%AF%EB%8D%B0%EC%9B%94%EB%93%9C%ED%83%80%EC%9B%8C&ijn=1&start=100&tbs=cdr%3A1%2Ccd_min%3A01%2F01%2F2019%2Ccd_max%3A11%2F30%2F2019&tbm=isch
# ...

# %%
pip install icrawler
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
